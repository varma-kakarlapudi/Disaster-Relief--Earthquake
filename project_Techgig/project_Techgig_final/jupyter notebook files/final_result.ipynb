# %%
a=138.2028
b=36.2048
from mpl_toolkits.basemap import Basemap

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

data=pd.read_csv('database.csv')
x=data[(data["Longitude"] > a-15) & (data["Longitude"] < a+15) & (data["Latitude"] > b-15) & (data["Latitude"] < b+15) ]


l1=list(x["Longitude"])
l2=list(x["Latitude"])
m1=list(x["Magnitude"])
s=sum(m1)
l=len(m1)
avg=s//l
print(s,l,avg)
print(len(l1),len(l2),len(m1))


n = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')
x,y = n(a,b)
fig3 = plt.figure(3,figsize=(12,10))
plt.title("Highly affected areas")
n.plot(x,y, "o", markersize = 35, color = 'green')
n.drawcoastlines()
n.fillcontinents(color='coral',lake_color='aqua')
n.drawmapboundary()
n.drawcountries()
#n.bluemarble()

plt.show()
# Out:
# 14139.000000000087 2397 5.0
# 2397 2397 2397

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='ortho', 
              lat_0=0, lon_0=0)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

x, y = map(13, 79)

map.plot(x, y, marker='D',color='r')

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='mill', 
              lat_0=0, lon_0=0)
fig3 = plt.figure(3,figsize=(17,12))
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

lons = [-10, -20, -25, -10, 0, 10]
lats = [40, 30, 10, 0, 0, -5]

x, y = map(lons, lats)

map.plot(x, y, marker=None,color='r')

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import pandas as pd
import matplotlib.pyplot as plt


'''map = Basemap(projection='ortho', 
              lat_0=0, lon_0=0)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

lons = [-10, -20, -25, -10, 0, 10]
lats = [40, 30, 10, 0, 0, -5]

x, y = map(lons, lats)

map.plot(x, y, marker=None,color='m')

plt.show()'''

data=pd.read_csv('database.csv')

highly_affected = data[data['Magnitude']>=9]


longitudes = highly_affected["Longitude"].tolist()
latitudes = highly_affected["Latitude"].tolist()

print(longitudes,latitudes)

print(latitudes,longitudes)
map = Basemap(projection='ortho', 
              lat_0=0, lon_0=0)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

lons = [0, 10, -20, -20]
lats = [0, -10, 40, -20]

x, y = map(lons, lats)

map.plot(x, y, marker='D',color='m')

plt.show()
minimum = data["Magnitude"].min()
maximum = data["Magnitude"].max()
average = data["Magnitude"].mean()

print("Minimum:", minimum)
print("Maximum:",maximum)
print("Mean",average)
# Out:
# [95.98200000000001, 142.373] [3.295, 38.297]
# [3.295, 38.297] [95.98200000000001, 142.373]
# Minimum: 5.5
# Maximum: 9.1
# Mean 5.882530753460003

# %%
def division(data):
    north_n=sum(data["Latitude"] >=30)
    middle_n=sum(np.logical_and(data["Latitude"]<30, data["Latitude"]>-30))
    south_n=sum(data["Latitude"]<= -30)
    #precentage
    total=north_n+middle_n+south_n
    north_p=north_n/total*100
    middle_p=middle_n/total*100
    south_p=south_n/total*100
    return north_n,middle_n,south_n,north_p,middle_p,south_p

eq=division(data)


print("There were",eq[0],"earthquakes in latitude over 30N",eq[1],
      "in latitude between 30N and 30S and",eq[2],
      "in latitude over 30S. In precentage it is %.2f%%"% eq[3],",",
      "%.2f%%"% eq[4],"and","%.2f%%"% eq[5],"respectively.")
# Out:
# There were 5323 earthquakes in latitude over 30N 15022 in latitude between 30N and 30S and 3067 in latitude over 30S. In precentage it is 22.74% , 64.16% and 13.10% respectively.

# %%
a=138.2024
b=36.2048

x=data[(data["Longitude"] > a-15) & (data["Longitude"] < a+15) & (data["Latitude"] > b-15) & (data["Latitude"] < b+15) ]


lon=data[(data["Longitude"] > a-15) & (data["Longitude"] < a+15) ]
lat=data[(data["Latitude"] > b-15) & (data["Latitude"] < b+15) ]


l1=list(x["Longitude"])
l2=list(x["Latitude"])
m1=list(x["Magnitude"])
s=sum(m1)
l=len(m1)
avg=s//l
#print(len(l1),len(l2),len(m1))

average = x["Magnitude"].mean()
minimum = x["Magnitude"].min()
maximum = x["Magnitude"].max()
print(maximum)
print(minimum)
print(average)
#average = data["Magnitude"].mean()


from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='mill', 
              lat_0=0, lon_0=0)
fig3 = plt.figure(3,figsize=(17,12))
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()



x, y = map(l1,l2)

map.scatter(x, y, marker=None,color='r')
x,y=map(138,36)
map.scatter(x,y,marker='D',color='g')
plt.show()
# Out:
# 9.1
# 5.5
# 5.89862327909891

# %%
l1=list(x["Longitude"])
l2=list(x["Latitude"])
m1=list(x["Magnitude"])
s=sum(m1)
l=len(m1)
avg=s//l
print(s,l,avg)
print(len(l1),len(l2),len(m1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c4d763fdc484> in <module>
#       2
#       3
# ----> 4 l1=list(x["Longitude"])
#       5 l2=list(x["Latitude"])
#       6 m1=list(x["Magnitude"])
#
# TypeError: list indices must be integers or slices, not str

# %%
from mpl_toolkits.basemap import Basemap
import pandas as pd
import matplotlib.pyplot as plt


map = Basemap(projection='mill', 
              lat_0=0, lon_0=0)
fig3 = plt.figure(9,figsize=(19,10))
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

#l1=list(x["Longitude"])
#l2=list(x["Latitude"])


x, y = map(l1, l2)

map.scatter(x, y, marker=None,color='m')
x,y=map(79.49,13.14)
x2,y2=map(110,110)
map.plot(x,y, "o", markersize = 15, color = 'green')
plt.annotate('sriharipuram',xy=(x, y),  xycoords='data',
                xytext=(x2, y2), textcoords='data',
                arrowprops=dict(arrowstyle="fancy")
                )
plt.show()

# %%
import tkinter
 
window = tkinter.Tk()
import tkinter
 
window = tkinter.Tk()
 
# to rename the title of the window window.title("GUI")
 
# pack is used to show the object in the window
 
#label = tkinter.Label(window, text = "Hello World!").pack()

bt = Button (window, text="Enter")
 
bt.grid (column=1, row=0)
window.mainloop()

# %%
from tkinter import *

r = Tk()
l1=Label(r, text="Enter Latitude").grid(row=0)
l1.pack()
l2=Label(r, text="Enter Longitude").grid(row=1)
l2.pack()

def inp():
    print("hello")

e1 = ttk.Entry(r)
e2 = ttk.Entry(r)

e1.grid(row=0, column=1)
e2.grid(row=1, column=1)

btn1 = Button(r, height=1, width=5, text="Submit")
btn1.pack()
btn1.config(command=inp())

r.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-7e2e21007718> in <module>
#       4 r = Tk()
#       5 l1=Label(r, text="Enter Latitude").grid(row=0)
# ----> 6 l1.pack()
#       7 l2=Label(r, text="Enter Longitude").grid(row=1)
#       8 l2.pack()
#
# AttributeError: 'NoneType' object has no attribute 'pack'

# %%
from tkinter import *
from tkinter import ttk
root=Tk()
def retrieve_input():
    inputValue=textBox.get("1.0","end-1c")
    print(inputValue)

textBox=Text(root, height=2, width=10)
textBox.pack()
buttonCommit=Button(root, height=1, width=10, text="Commit", 
                    command=lambda: retrieve_input())
#command=lambda: retrieve_input() >>> just means do this when i press the button
buttonCommit.pack()

mainloop()

# %%
from tkinter import *

from tkinter import messagebox
messagebox.showinfo('Message title’, 'Message content')
                    
r = Tk()
l1=Label(r, text="Enter Latitude").grid(row=0)
#l1.pack()
l2=Label(r, text="Enter Longitude").grid(row=1)
#l2.pack()

def inp():
    messagebox.showinfo('demo', 'latitude and longitude')

e1 = Entry(r)
e2 = Entry(r)

e1.grid(row=0, column=1)
e2.grid(row=1, column=1)

btn1 = Button(r, height=1, width=5, text="Submit")
#btn1.pack()
btn1.grid(row=2,column=1)
btn1.config(command=inp())

r.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-6a57e504f856> in <module>
#      19 #btn1.pack()
#      20 btn1.grid(row=2,column=1)
# ---> 21 btn1.config(command=inp())
#      22
#      23 r.mainloop()
#
# <ipython-input-66-6a57e504f856> in inp()
#       8
#       9 def inp():
# ---> 10     messagebox.showinfo('demo', 'latitude and longitude')
#      11
#      12 e1 = Entry(r)
#
# NameError: name 'messagebox' is not defined

# %%
#a=138.2029     #longitude      #japan
#b=36.2049   #latitude

#a=79.47 longitude
#b=13.45 latitude    #sriharipuram , india

b = float(input("Enter Latitude :"))
a = float(input("Enter Longitude :"))
import pandas as pd
import numpy as np

data=pd.read_csv('database.csv')
x=data[(data["Longitude"] > a-15) & (data["Longitude"] < a+15) & (data["Latitude"] > b-15) & (data["Latitude"] < b+15) ]


l1=list(x["Longitude"])
l2=list(x["Latitude"])
m1=list(x["Magnitude"])

minimum = data["Magnitude"].min()
maximum = data["Magnitude"].max()
average = data["Magnitude"].mean()

print("The Minimum Magnitude occured in is : ",minimum)
print("The Maximum Magnitude occured is : ",maximum)
print("The Average Magnitude occured is : ",average)
if(avg > 8):
    print("\nGreat Earthquake\nItcan totally destroy communities\n Hence it's not safe and is not recommended to invest heavy budgets in this location .")
elif(avg > 7):
    print("\nMajor Earthquake\nIt can cause Serious Damage\nhence it's not safe and is not recommended to invest more budget in this location .")
elif( avg > 6):
    print("\nMay cause a lot of damage in very populated areas\nInvesting in this location is a bit Risky ..")
elif(avg > 5):
    print("\nMay cause slight Damage to Buildings and other Structures \nInvesting in this location is bit risky ..")
elif( avg > 3.5 ):
    print("\nEarthquake is often felt but causes minor damage\nthere may be no human loss \nIts a bit safer to invest in this Locality ..")
else:
    print("\nUsually not felt but can be recorded by seismograph \nIts safe to invest in this location \nIt can be recommended for constructing buildings with heavy investments .")
 
from mpl_toolkits.basemap import Basemap

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
n = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=0, llcrnrlon=-0,urcrnrlon=180,lat_ts=20,resolution='c')
x,y = n(l1,l2)
fig3 = plt.figure(3,figsize=(12,10))
plt.title("Nearby Affected Areas ")
n.plot(x,y, "o", markersize = 3, color = 'g')

x,y = n(a,b)
n.plot(x,y, "o", markersize = 6, color = 'blue')
n.drawcoastlines()
n.fillcontinents(color='coral',lake_color='aqua')
x,y=n(50,30)
x2,y2 =(a,b)

n.drawmapboundary()
n.drawcountries()
n.bluemarble()

plt.show()
# Out:
# Enter Latitude :13.45
# Enter Longitude :79.69
# The Minimum Magnitude occured is :  5.5
# The Maximum Magnitude occured is :  9.1
# The Average Magnitude occured is :  5.882530753460003
#
# Earthquake is often felt but causes minor damage
# there may be no human loss
# Its a bit safer to invest in this Locality ..
