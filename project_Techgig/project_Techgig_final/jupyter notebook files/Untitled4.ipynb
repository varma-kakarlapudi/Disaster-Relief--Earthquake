# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

data = pd.read_csv('database.csv')

data2 = pd.get_dummies(data, columns =['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error', 'Depth Seismic Stations', 'Magnitude', 'Magnitude Type', 'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID', 'Source', 'Location Source', 'Magnitude Source', 'Status'] )


X = data2.iloc[:,1:]
y = data2.iloc[:,0]


#---------->    Split dataset into training set and test set

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

X_train.shape


#---------->    It shows Training data after splitting

#Create a Gaussian Classifier

gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)



# ---------> Model Accuracy, how often is the classifier correct?

print('Accuracy of Naive_bayes classifier on test set: {:.2f}'.format(gnb.score(X_train, y_train)))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-1-3ddbdbdeda82> in <module>
#       9
#      10
# ---> 11 X = data2.iloc[:,1:]
#      12 y = data2.iloc[:,0]
#      13
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2157                 continue
#    2158
# -> 2159             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    2160
#    2161             # if the dim was reduced, then pass a lower-dim the next time
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2208
#    2209         if isinstance(key, slice):
# -> 2210             return self._get_slice_axis(key, axis=axis)
#    2211
#    2212         if isinstance(key, list):
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2178         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2179         if isinstance(slice_obj, slice):
# -> 2180             return self._slice(slice_obj, axis=axis, kind='iloc')
#    2181         else:
#    2182             return self.obj._take(slice_obj, axis=axis)
#
# ~\Anaconda2\lib\site-packages\pandas\core\indexing.py in _slice(self, obj, axis, kind)
#     149         if axis is None:
#     150             axis = self.axis
# --> 151         return self.obj._slice(obj, axis=axis, kind=kind)
#     152
#     153     def _get_setitem_indexer(self, key):
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis, kind)
#    3160         """
#    3161         axis = self._get_block_manager_axis(axis)
# -> 3162         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    3163         result = result.__finalize__(self)
#    3164
#
# ~\Anaconda2\lib\site-packages\pandas\core\internals\managers.py in get_slice(self, slobj, axis)
#     698
#     699         bm = self.__class__(new_blocks, new_axes, do_integrity_check=False)
# --> 700         bm._consolidate_inplace()
#     701         return bm
#     702
#
# ~\Anaconda2\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     927     def _consolidate_inplace(self):
#     928         if not self.is_consolidated():
# --> 929             self.blocks = tuple(_consolidate(self.blocks))
#     930             self._is_consolidated = True
#     931             self._known_consolidated = True
#
# ~\Anaconda2\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1897     for (_can_consolidate, dtype), group_blocks in grouper:
#    1898         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 1899                                       _can_consolidate=_can_consolidate)
#    1900         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    1901     return new_blocks
#
# ~\Anaconda2\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3147
#    3148         argsort = np.argsort(new_mgr_locs)
# -> 3149         new_values = new_values[argsort]
#    3150         new_mgr_locs = new_mgr_locs[argsort]
#    3151
#
# MemoryError:

# %%
# Importing predefined libraries required

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

plt.rc("font", size=14)

from sklearn.model_selection import cross_validate

# --------->  Using NAIVE_BAYES CLASSIFIER 

from sklearn import naive_bayes
from sklearn.naive_bayes import GaussianNB



from sklearn.model_selection import train_test_split

import seaborn as sns

sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

#Here database.csv is the data on which basis we are going to predict. Make sure that both the files are in the same folder for succesful execution.

# Replace the file path below based on where the file is placed before running the code
data = pd.read_csv('database.csv')
print(data)
#data.head()
data = data.dropna()
print(data.shape)
print(list(data.columns))

# BAR PLOT  for our required data can be obtained with below syntax :

"""sns.countplot(x='Location Source',data=data, palette='hls')"""
sns.countplot(x='Magnitude Source',data=data, palette='hls') 

#sns.countplot(x='Horizontal Error',data=data, palette='hls')


plt.show()

# --------->    Checking null values:

data.isnull().sum()

data2 = pd.get_dummies(data, columns =['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error', 'Depth Seismic Stations', 'Magnitude', 'Magnitude Type', 'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID', 'Source', 'Location Source', 'Magnitude Source', 'Status'] )


#---------->    To drop unknown coloumns 

sns.heatmap(data2.corr())
plt.show()


# To find correlation

#---------->    Train the model using the training sets


X = data2.iloc[:,1:]
y = data2.iloc[:,0]


#---------->    Split dataset into training set and test set

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

X_train.shape


#---------->    It shows Training data after splitting

#Create a Gaussian Classifier

gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)



# ---------> Model Accuracy, how often is the classifier correct?

#print('Accuracy of Naive_bayes classifier on test set: {:.2f}'.format(gnb.score(X_train, y_train)))



""" ANOTHER METHOD for accuracy checking"""

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0        1/2/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1        1/4/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2        1/5/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3        1/8/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4        1/9/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# 23389          3.4                     NaN        5.9            MWW  ...
# 23390          1.6                     NaN        5.5            MWB  ...
# 23391          1.6                     NaN        5.9            MWW  ...
# 23392          2.9                     NaN        6.2            MWW  ...
# 23393          5.2                     NaN        5.5             MB  ...
# 23394          3.1                     NaN        6.4            MWW  ...
# 23395          2.8                     NaN        6.4            MWW  ...
# 23396          1.7                     NaN        5.6            MWW  ...
# 23397          1.6                     NaN        6.0            MWW  ...
# 23398          3.2                     NaN        5.5            MWB  ...
# 23399          1.8                     NaN        6.7            MWW  ...
# 23400          2.9                     NaN        5.9            MWW  ...
# 23401          1.9                     NaN        6.0            MWW  ...
# 23402          1.8                     NaN        5.8            MWW  ...
# 23403          1.9                     NaN        7.6            MWW  ...
# 23404          3.3                     NaN        5.6             MB  ...
# 23405          1.8                     NaN        5.6            MWW  ...
# 23406          1.3                    34.0        5.6             ML  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                             NaN            NaN                  NaN
# 1                             NaN            NaN                  NaN
# 2                             NaN            NaN                  NaN
# 3                             NaN            NaN                  NaN
# 4                             NaN            NaN                  NaN
# 5                             NaN            NaN                  NaN
# 6                             NaN            NaN                  NaN
# 7                             NaN            NaN                  NaN
# 8                             NaN            NaN                  NaN
# 9                             NaN            NaN                  NaN
# 10                            NaN            NaN                  NaN
# 11                            NaN            NaN                  NaN
# 12                            NaN            NaN                  NaN
# 13                            NaN            NaN                  NaN
# 14                            NaN            NaN                  NaN
# 15                            NaN            NaN                  NaN
# 16                            NaN            NaN                  NaN
# 17                            NaN            NaN                  NaN
# 18                            NaN            NaN                  NaN
# 19                            NaN            NaN                  NaN
# 20                            NaN            NaN                  NaN
# 21                            NaN            NaN                  NaN
# 22                            NaN            NaN                  NaN
# 23                            NaN            NaN                  NaN
# 24                            NaN            NaN                  NaN
# 25                            NaN            NaN                  NaN
# 26                            NaN            NaN                  NaN
# 27                            NaN            NaN                  NaN
# 28                            NaN            NaN                  NaN
# 29                            NaN            NaN                  NaN
# ...                           ...            ...                  ...
# 23382                         NaN          45.00                2.203
# 23383                         NaN          18.00                6.124
# 23384                         NaN          18.00                5.994
# 23385                         NaN          63.00                1.367
# 23386                         NaN          13.00                1.389
# 23387                        81.0          54.00                1.393
# 23388                         NaN          31.00                2.331
# 23389                         NaN          13.00                1.469
# 23390                         8.0          65.00               27.654
# 23391                         NaN          25.00                3.026
# 23392                         NaN          16.00                8.779
# 23393                       147.0          92.00                1.458
# 23394                         NaN          11.00                2.804
# 23395                         NaN          21.00                1.456
# 23396                         NaN          15.00                7.182
# 23397                         NaN          14.00                1.204
# 23398                        41.0          19.00                1.087
# 23399                         NaN          17.00                3.380
# 23400                         NaN          21.00                6.239
# 23401                         NaN          13.00                1.753
# ['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error', 'Depth Seismic Stations', 'Magnitude', 'Magnitude Type', 'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID', 'Source', 'Location Source', 'Magnitude Source', 'Status']
# Accuracy: 1.0

# %%
from mpl_toolkits.basemap import Basemap

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

data = pd.read_csv('database.csv')

m = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')

longitudes = data["Longitude"].tolist()
latitudes = data["Latitude"].tolist()
#m = Basemap(width=12000000,height=9000000,projection='lcc',
            #resolution=None,lat_1=80.,lat_2=55,lat_0=80,lon_0=-107.)
x,y = m(longitudes,latitudes)
fig = plt.figure(figsize=(20,50))
plt.title("All affected areas")
m.plot(x, y, "o", markersize = 2, color = 'blue')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary()
m.drawcountries()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

data = pd.read_csv('database.csv')
l=[]
l=data.comunns
df = pd.DataFrame(l,columns['Mangnitude'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f6a4be530e94> in <module>
#       6 data = pd.read_csv('database.csv')
#       7 l=[]
# ----> 8 l=data.comunns
#       9 df = pd.DataFrame(l,columns['Mangnitude'])
#      10 print(df)
#
# ~\Anaconda2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'comunns'

# %%
from mpl_toolkits.basemap import Basemap

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

data = pd.read_csv('database.csv')

m = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')

longitudes = data["Longitude"].tolist()
latitudes = data["Latitude"].tolist()
#m = Basemap(width=12000000,height=9000000,projection='lcc',
            #resolution=None,lat_1=80.,lat_2=55,lat_0=80,lon_0=-107.)
x,y = m(longitudes,latitudes)
fig = plt.figure(figsize=(20,50))
plt.title("All affected areas")
m.plot(x, y, "o", markersize = 2, color = 'blue')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary()
m.drawcountries()
plt.show()


minimum = data["Magnitude"].min()
maximum = data["Magnitude"].max()
average = data["Magnitude"].mean()

print("Minimum:", minimum)
print("Maximum:",maximum)
print("Mean",average)
# Out:
# Minimum: 5.5
# Maximum: 9.1
# Mean 5.882530753460003

# %%
from mpl_toolkits.basemap import Basemap

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

highly_affected = data[data['Magnitude']>=8]

longitudes = highly_affected["Longitude"].tolist()
latitudes = highly_affected["Latitude"].tolist()

print(longitudes,latitudes)

n = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')
x,y = n(longitudes,latitudes)
fig3 = plt.figure(9,figsize=(12,10))
plt.title("Highly affected areas")
n.plot(x,y, "o", markersize = 15, color = 'green')
n.drawcoastlines()
n.fillcontinents(color='coral',lake_color='aqua')
n.drawmapboundary()
n.drawcountries()
plt.show()
# Out:
# [125.95200000000001, 178.715, -78.22800000000001, 143.435, -72.532, 153.85, 153.172, 126.64, -177.657, -71.87100000000001, -102.53299999999999, -174.77599999999998, 160.56799999999998, -67.553, 147.321, -70.294, -104.205, 136.952, 149.52700000000002, 152.16899999999998, -73.641, 143.91, 161.345, 95.98200000000001, 97.10799999999999, -174.123, 153.266, 154.524, 157.043, -76.60300000000001, 101.367, -172.095, -72.898, 142.373, 93.06299999999999, 92.463, 165.114, 153.221, -70.7691, -71.6744] [-2.608, 51.251000000000005, -10.665, 40.86, -1.597, -5.524, -4.817, 6.405, -28.427, -33.135, 18.19, 51.52, -52.341, -13.841, 43.773, -23.34, 19.055, -0.8909999999999999, -62.876999999999995, -3.98, -16.265, 41.815, -49.312, 3.295, 2.085, -20.187, 46.592, 46.243, -8.466000000000001, -13.386, -4.438, -15.489, -36.122, 38.297, 2.327, 0.802, -10.799000000000001, 54.891999999999996, -19.6097, -31.5729]

# %%
a = int(input("enter latitude : "))
# Out:
# enter latitude :  35

# %%
b= int(input("enter latitude : "))
# Out:
# enter latitude :  56

# %% [markdown]
# highly_affected = data[data['Magnitude']>=9]
#
# s1=38.391
# s2=-118.894
#
# longitudes = highly_affected["Longitude"].tolist()
# latitudes = highly_affected["Latitude"].tolist()
#
# print(longitudes,latitudes)
#
# n = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')
# x,y = n(latitudes,longitudes)
# fig3 = plt.fig
# ure(9,figsize=(12,10))
# plt.title("Highly affected areas")
# n.plot(,y, "o", markersize = 50, color = 'green')
# n.drawcoastlines()
# n.fillcontinents(color='coral',lake_color='aqua')
# n.drawmapboundary()
# n.drawcountries()
# plt.show()

# %%
from mpl_toolkits.basemap import Basemap

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt
n = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')

fig3 = plt.figure(9,figsize=(12,10))
plt.title("Highly affected areas")
n.plot(a,b, "o", markersize = 50, color = 'green')
n.drawcoastlines()
n.fillcontinents(color='coral',lake_color='aqua')
n.drawmapboundary()
n.drawcountries()
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
# set resolution=None to skip processing of boundary datasets.
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
m.bluemarble()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
a=79.49     #longitude
b=13.167    #latitude
import pandas as pd
import numpy as np

data=pd.read_csv('database.csv')
x=data[(data["Longitude"] > a-15) & (data["Longitude"] < a+15) & (data["Latitude"] > b-15) & (data["Latitude"] < b+15) ]


l1=list(x["Longitude"])
l2=list(x["Latitude"])
m1=list(x["Magnitude"])

avg = data["Magnitude"].mean()
print("The average earthquake is : ",avg)
if(avg > 8):
    print("\nGreat Earthquake\nItcan totally destroy communities\n Hence it's not safe and is not recommended to invest heavy budgets in this location .")
elif(avg > 7):
    print("\nMajor Earthquake\nIt can cause Serious Damage\nhence it's not safe and is not recommended to invest more budget in this location .")
elif( avg > 6):
    print("\nMay cause a lot of damage in very populated areas\nInvesting in this location is a bit Risky ..")
elif(avg > 5):
    print("\nMay cause slight Damage to Buildings and other Structures \nInvesting in this location is bit risky ..")
elif( avg > 3.5 ):
    print("\nEarthquake is often felt but causes minor damage\nthere may be no human loss \nIts a bit safer to invest in this Locality ..")
else:
    print("\nUsually not felt but can be recorded by seismograph \nIts safe to invest in this location \nIt can be recommended for constructing buildings with heavy investments .")
# Out:
# The average earthquake is :  5.882530753460003
#
# May cause slight Damage to Buildings and other Structures
# Investing in this location is bit risky ..

# %%
# Importing predefined libraries required

import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt

plt.rc("font", size=14)

from sklearn.model_selection import cross_validate

# --------->  Using NAIVE_BAYES CLASSIFIER 

from sklearn import naive_bayes
from sklearn.naive_bayes import GaussianNB



from sklearn.model_selection import train_test_split

import seaborn as sns

sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

#Here database.csv is the data on which basis we are going to predict. Make sure that both the files are in the same folder for succesful execution.

# Replace the file path below based on where the file is placed before running the code
data = pd.read_csv('database.csv')
#print(data)
#data.head()
#data = data.dropna()


data_clean=data.drop(['Depth Error','Depth Seismic Stations','Magnitude Error','Magnitude Seismic Stations','Azimuthal Gap','Horizontal Distance','Horizontal Error','Root Mean Square'],axis=1)
data_clean=data_clean.dropna()
data_clean=data_clean.drop(['Date','Time','Type'],axis=1)
data_clean=data_clean.drop(['ID','Source','Location Source','Magnitude Source','Status'],axis=1)

#data_clean[data_clean[0::,0].astype(np.float) >= 'Magnitude Type', 5] = 'Magnitude Type'-1.0
print(data_clean.shape)

X = data_clean.iloc[:,0:4]


y = data_clean.iloc[:,4:5]

X=X.astype('float')
y=y.astype('str')
#---------->    Split dataset into training set and test set

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

X_train.shape

#---------->    It shows Training data after splitting

#Create a Gaussian Classifier

gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)



# ---------> Model Accuracy, how often is the classifier correct?

print('Accuracy of Naive_bayes classifier on test set: {:.2f}\n\n'.format(gnb.score(X_train, y_train)*100,2))



# ANOTHER METHOD for accuracy checking

from sklearn import metrics
print("Accuracy:",100-metrics.accuracy_score(y_test, y_pred)*100)

#x2=np.array([36.2048,138.2029])
#x2 = data_clean
#x1 = gnb.predict_proba(x2)

#print(x1)
# Out:
# (23409, 5)
# Accuracy of Naive_bayes classifier on test set: 21.63
#
#
# Accuracy: 78.96805057235606
# C:\Users\Sairam Potnuru\Anaconda2\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
